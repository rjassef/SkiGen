# %%
#Load SkiGen
from skiGen import SkiGen
import subprocess

# %%
#Delete all the previous scripts.
subprocess.call("rm -rf scripts/*", shell=True)
# Out:
# 0

# %%
#Set the object with a full cone (i.e., top and bottom halfs).
ski = SkiGen(cone_tau=0.1, cone_width=10, cone_dust_type='mrn77', SED_only=True)
ski.write_files_parameter_grid(tor_oa_min=25,tor_oa_max=60,tor_doa=5,cone_oa_min=10,cone_oa_max=55,cone_doa=5)
# Out:
# mkdir: scripts: File exists

# %%
#Bottom cone only
ski = SkiGen(cone_tau=0.1, cone_width=10, cone_dust_type='mrn77', SED_only=True, cone_type="Bottom")
ski.write_files_parameter_grid(tor_oa_min=25,tor_oa_max=60,tor_doa=5,cone_oa_min=10,cone_oa_max=55,cone_doa=5)
# Out:
# mkdir: scripts: File exists

# %%
#Top cone only
ski = SkiGen(cone_tau=0.1, cone_width=10, cone_dust_type='mrn77', SED_only=True, cone_type="Top")
ski.write_files_parameter_grid(tor_oa_min=25,tor_oa_max=60,tor_doa=5,cone_oa_min=10,cone_oa_max=55,cone_doa=5)
# Out:
# mkdir: scripts: File exists
