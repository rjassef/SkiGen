# %%
#Load SkiGen
from skiGen import SkiGen
import subprocess

# %%
#Delete all the previous scripts.
subprocess.call("rm -rf full_inst_scripts/*", shell=True)
# Out:
# 0

# %%
#Set the object with a full cone (i.e., top and bottom halfs).
ski = SkiGen(cone_tau=0.1, cone_width=10, cone_dust_type='mrn77', SED_only=False)
ski.write_files_parameter_grid(tor_oa_min=45,tor_oa_max=45,tor_doa=5,cone_oa_min=35,cone_oa_max=35,cone_doa=5, etas=[80.0], folder="full_inst_scripts/")
# Out:
# mkdir: cannot create directory ‘full_inst_scripts/’: File exists

# %%
#Bottom cone only
ski = SkiGen(cone_tau=0.1, cone_width=10, cone_dust_type='mrn77', SED_only=True, cone_type="Bottom")
ski.write_files_parameter_grid(tor_oa_min=45,tor_oa_max=45,tor_doa=5,cone_oa_min=35,cone_oa_max=35,cone_doa=5, etas=[80.0], folder="full_inst_scripts/")
# Out:
# mkdir: cannot create directory ‘full_inst_scripts/’: File exists

# %%
#Top cone only
ski = SkiGen(cone_tau=0.1, cone_width=10, cone_dust_type='mrn77', SED_only=True, cone_type="Top")
ski.write_files_parameter_grid(tor_oa_min=45,tor_oa_max=45,tor_doa=5,cone_oa_min=35,cone_oa_max=35,cone_doa=5, etas=[80.0], folder="full_inst_scripts/")
# Out:
# mkdir: cannot create directory ‘full_inst_scripts/’: File exists
